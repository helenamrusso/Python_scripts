# %% [markdown]
# ## FBMN - Filter MGF from MZmine
#
# The script takes a input feature quantification table and MGF file from [feature-based molecular networking (FBMN)](https://ccms-ucsd.github.io/GNPSDocumentation/featurebasedmolecularnetworking/) and output a filtered MGF with spectra for only the feature IDs present in the feature quantification table. These files can then be used to generate a FBMN that was prefiltered.

# %%
from filter_mgf_MZmine import *

# %% [markdown]
# #### Drag and drop your input files in the jupyter lab environment (left panel)
#
# #### Replace the filenames in the function below.
# The format looks like:
# `filter_mgf('mzmine_feature_quant_table.csv','mzmine_MS2_spectral_summary.mgf')`
# #### Run the cell.

# %%
filter_mgf('example_files/FeaturesToDelete_NEG.csv','example_files/NEG_GNPSinput.mgf')

# %% [markdown]
# #### Download your filtered MGF file (left panel and right click to download)
